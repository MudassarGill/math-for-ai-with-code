# %%
print("Hello world")
# Out:
# Hello world

# %%
x='Mudassar'
print(x)
# Out:
# Mudassar

# %%
#type function that we need to return the type of any varible

type(x)
# Out:
# str

# %%
number=90
type(number)
# Out:
# int

# %%
a=100
b=200
print(id(a),id(b))
# Out:
# 2318701038928 2318701042128

# %%
number=input("enter your number")
print(type(number))
# Out:
# <class 'str'>

# %%
#swap two number

a=20
b=30
print(f'without swaping {a }    and    {b}')
a,b=b,a
print(f'after swaping {a }    and    {b}')
# Out:
# without swaping 20    and    30
# after swaping 30    and    20

# %%
value="123"
covert=int(value)
type(covert)
# Out:
# int

# %%
#operations

a =10
b=20

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 30
# -10
# 200
# 0.5
# 10

# %%
firstname="Mudassar"
lastname="Hussain"
print(firstname + ' '+lastname)
# Out:
# Mudassar Hussain

# %%
#string method

print(firstname.upper())
print(firstname.lower())
print(firstname.capitalize())
print(firstname.islower())
print(firstname.isalpha())
# Out:
# MUDASSAR
# mudassar
# Mudassar
# False
# True

# %%
#list and all method about list
from numpy.testing import print_assert_equal

list1=[2,3,4,5,6]
print([0])
# Out:
# [0]

# %%
fruits=['banna','charry','apple']
fruits[1]='orange'
print(fruits)
# Out:
# ['banna', 'orange', 'apple']

# %%
#add item here
fruits.append('mango')
fruits
# Out:
# ['banna', 'orange', 'apple', 'mango']

# %%
fruits[1:]
# Out:
# ['orange', 'apple', 'mango']

# %%
#remove item that we add here

fruits.remove('mango')
fruits
# Out:
# ['banna', 'orange', 'apple']

# %%
list2=[45,3,4,55,66,7,8,94]

list2.sort()

# %%
list2
# Out:
# [3, 4, 7, 8, 45, 55, 66, 94]

# %%
print(list2[-2])
# Out:
# 66

# %%
for item in fruits:
    print(f'Index {item.index} Item {item}')
# Out:
# Index <built-in method index of str object at 0x0000021BE9C84770> Item banna
# Index <built-in method index of str object at 0x0000021BE9C847F0> Item orange
# Index <built-in method index of str object at 0x0000021BE9C84370> Item apple

# %%
sets={2,2,2,3,4,5,6}
print(sets)
# Out:
# {2, 3, 4, 5, 6}

# %%
student = {
    "name": "Ali",
    "age": 22,
    "city": "Karachi"
}
print(student)
# Out:
# {'name': 'Ali', 'age': 22, 'city': 'Karachi'}
