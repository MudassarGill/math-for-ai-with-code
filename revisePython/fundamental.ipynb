# %%
print("Hello world")
# Out:
# Hello world

# %%
x='Mudassar'
print(x)
# Out:
# Mudassar

# %%
#type function that we need to return the type of any varible

type(x)
# Out:
# str

# %%
number=90
type(number)
# Out:
# int
